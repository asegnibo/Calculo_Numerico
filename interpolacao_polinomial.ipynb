# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv(r'C:\Users\ashton.segnibo_capim\Documents\Python\Calculo_Numerico\Grupo02 (1).csv', sep = ';').replace(',','.')
dados['Precipitação']=dados['Precipitação'].str.replace(',','.')
dados['Precipitação'] = dados['Precipitação'].astype(float)
dados
# Out:
#     Mês  Precipitação
# 0     1         144.4
# 1     2         150.0
# 2     3         125.8
# 3     4          94.0
# 4     5         111.0
# 5     6         262.2
# 6     7         149.8
# 7     8         186.0
# 8     9         188.4
# 9    10         231.3
# 10   11         341.4
# 11   12         182.7
# 12   13         149.6
# 13   14          82.4
# 14   15          84.0
# 15   16          35.9
# 16   17          40.3
# 17   18         207.0
# 18   19          82.4
# 19   20         250.0
# 20   21         237.2
# 21   22         101.2
# 22   23         242.7
# 23   24          60.4
# 24   25          43.2
# 25   26           0.0
# 26   27           1.1
# 27   28          33.1
# 28   29          22.3
# 29   30          17.1
# 30   31         115.3
# 31   32         193.2
# 32   33         130.4
# 33   34         397.8
# 34   35         239.0
# 35   36         153.6
# 36   37         141.4
# 37   38          82.6
# 38   39          80.8
# 39   40          15.6
# 40   41          11.8
# 41   42          88.0
# 42   43          90.0
# 43   44         196.6
# 44   45         189.2
# 45   46         234.2
# 46   47          55.4
# 47   48          76.4
# 48   49         185.4
# 49   50         362.0
# 50   51         198.8
# 51   52          76.4
# 52   53           0.0
# 53   54          44.8
# 54   55         197.3
# 55   56         192.8
# 56   57          73.1
# 57   58         268.0
# 58   59          39.0
# 59   60          15.8

# %%
plt.scatter(dados['Mês'], dados['Precipitação'])
plt.ylim(0,450)
print(type(dados['Precipitação']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
dados['Mês'][0]

def lagrange_interpolation(x_points, y_points, x):
    """
    Calcula o valor interpolado usando o método de Lagrange.

    Args:
        x_points: Uma lista ou array numpy de coordenadas x dos pontos de dados.
        y_points: Uma lista ou array numpy de coordenadas y dos pontos de dados.
        x: O ponto no qual se deseja calcular a interpolação.

    Returns:
        O valor interpolado em x.
    """
    n = len(x_points)
    if n != len(y_points):
        raise ValueError("x_points e y_points devem ter o mesmo comprimento")

    interpolated_value = 0
    for i in range(n):
        term = y_points[i]
        for j in range(n):
            if i != j:
                term = term * (x - x_points[j]) / (x_points[i] - x_points[j])
        interpolated_value += term
    return interpolated_value
# Out:
# Valor real de sin(pi/4): 0.7071067811865476
# Valor interpolado em pi/4: 0.707106781186549

# %%
meses = dados['Mês']
precipitacoes = dados['Precipitação']

num_points = 60 
x_data = np.linspace(0, 2 * np.pi, num_points)
y_data = np.sin(x_data)


x_to_interpolate = np.pi / 4

y_interpolated = lagrange_interpolation(meses, precipitacoes, x_to_interpolate)

x_plot = np.linspace(min(meses), max(meses), 200)
y_plot_lagrange = [lagrange_interpolation(meses, precipitacoes, xp) for xp in x_plot]

plt.figure(figsize=(10, 6))
plt.plot(meses, precipitacoes, 'o', label='Pontos de Dados')
plt.plot(meses, precipitacoes, label='Polinômio de Lagrange')
plt.xlabel('x')
plt.ylabel('y')
plt.title(f'Interpolação de Lagrange com {num_points} pontos')
plt.legend()
plt.grid(True)
texto_correlacao = f"Correlação (Mês, Precipitação): {correlacao:.2f}"
plt.text(0.05, 0.05, texto_correlacao, transform=plt.gca().transAxes, fontsize=10, verticalalignment='bottom', bbox=dict(boxstyle='round,pad=0.5', fc='wheat', alpha=0.7))

plt.show()
